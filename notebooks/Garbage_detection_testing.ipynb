# %%
# mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install -q ultralytics

# %%
data = "/content/drive/MyDrive/Garbage_detection_system/Garbage_Final"

# %%
from ultralytics import YOLO

# %%
model = YOLO("/content/drive/MyDrive/Garbage_detection_system/Garbage_Training_Artifacts/weights/best.pt")

# %%
model.predict(
    source="/content/drive/MyDrive/Garbage_detection_system/Garbage_Final/test/images",
    save=True,
    conf=0.25
)
# Out:
# image 1/201 /content/drive/MyDrive/Garbage_detection_system/Garbage_Final/test/images/Aerial_Garbage_detection.yolov8_000005_jpg.rf.k0D8uG4lFwhHFMYGemkS.jpg: 640x640 2 garbages, 7.2ms
# image 2/201 /content/drive/MyDrive/Garbage_detection_system/Garbage_Final/test/images/Aerial_Garbage_detection.yolov8_000015_jpg.rf.ShE9jLxQenx248xgbNJi.jpg: 640x640 1 garbage, 7.2ms
# image 3/201 /content/drive/MyDrive/Garbage_detection_system/Garbage_Final/test/images/Aerial_Garbage_detection.yolov8_000017_jpg.rf.4eBwQpOBa0DijiviyN6L.jpg: 640x640 2 garbages, 42.1ms
# image 4/201 /content/drive/MyDrive/Garbage_detection_system/Garbage_Final/test/images/Aerial_Garbage_detection.yolov8_000026_jpg.rf.ehhWqu3WHmNmosR6UJe7.jpg: 640x640 1 garbage, 12.9ms
# image 5/201 /content/drive/MyDrive/Garbage_detection_system/Garbage_Final/test/images/Aerial_Garbage_detection.yolov8_000030_jpg.rf.6BQ8ZLRaHbzgr1qIJBo8.jpg: 640x640 1 garbage, 7.2ms
# ...

# %%
# !ls /content/runs/detect/predict
# Out:
#  Aerial_Garbage_detection.yolov8_000005_jpg.rf.k0D8uG4lFwhHFMYGemkS.jpg
#  Aerial_Garbage_detection.yolov8_000015_jpg.rf.ShE9jLxQenx248xgbNJi.jpg
#  Aerial_Garbage_detection.yolov8_000017_jpg.rf.4eBwQpOBa0DijiviyN6L.jpg
#  Aerial_Garbage_detection.yolov8_000026_jpg.rf.ehhWqu3WHmNmosR6UJe7.jpg
#  Aerial_Garbage_detection.yolov8_000030_jpg.rf.6BQ8ZLRaHbzgr1qIJBo8.jpg
#  Aerial_Garbage_detection.yolov8_000040_jpg.rf.zcIESVq92HnlOJx8CShU.jpg
#  Aerial_Garbage_detection.yolov8_000050_jpg.rf.tKSbNCIda8Zf1ds35PnL.jpg
#  Aerial_Garbage_detection.yolov8_000054_jpg.rf.l77M2ygaI4n8VXnkNpkU.jpg
#  Aerial_Garbage_detection.yolov8_000064_JPG_jpg.rf.52wZ3qzDToKfZ97qiI8h.jpg
#  Aerial_Garbage_detection.yolov8_000065_JPG_jpg.rf.RgsiyKchZTXsxXSPW8qz.jpg
#  Aerial_Garbage_detection.yolov8_000085_JPG_jpg.rf.kniAnBOlXIYg0R2wicZU.jpg
#  Aerial_Garbage_detection.yolov8_000096_JPG_jpg.rf.FMeWLmDqsyYS3at17MjB.jpg
#  Aerial_Garbage_detection.yolov8_batch_01_frame_17_jpg.rf.apx6INnPHi0xfczatTAM.jpg
# ...

# %%
from IPython.display import Image, display

display(Image('/content/drive/MyDrive/kachra.jpg'))

# %%
# !mkdir -p "/content/drive/MyDrive/Garbage_Testing_Results"

# !cp -r /content/runs/detect/predict/* \
"/content/drive/MyDrive/Garbage_Testing_Results/"
