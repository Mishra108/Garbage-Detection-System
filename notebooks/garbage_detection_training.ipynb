# %%
# mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -q ultralytics
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 1.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 20.3 MB/s eta 0:00:00

# %% [markdown]
# load dataset

# %%
data = "/content/drive/MyDrive/Colab Notebooks/Garbage_detection_system/Garbage_Final"

# %%
with open("/content/drive/MyDrive/Colab Notebooks/Garbage_detection_system/Garbage_Final/data.yaml", "w") as f:
    f.write("""
path: /content/drive/MyDrive/Colab Notebooks/Garbage_detection_system/Garbage_Final

train: train/images
val: valid/images
test: test/images

nc: 1

names:
  0: garbage
""")

# %%
with open("/content/drive/MyDrive/Colab Notebooks/Garbage_detection_system/Garbage_Final/data.yaml") as f:
    print(f.read())
# Out:
# path: /content/drive/MyDrive/Colab Notebooks/Garbage_detection_system/Garbage_Final
#
# train: train/images
# val: valid/images
# test: test/images
#
# nc: 1
#
# names:
#   0: garbage

# %%
import os

base = "/content/drive/MyDrive/Colab Notebooks/Garbage_detection_system/Garbage_Final"

print(os.path.exists(base))
print(os.path.exists(base + "/train/images"))
print(os.path.exists(base + "/valid/images"))
print(os.path.exists(base + "/test/images"))
# Out:
# True
# True
# True
# True

# %% [markdown]
# Train

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO("yolov8n.pt")

# %%
results = model.train(
    data="/content/drive/MyDrive/Colab Notebooks/Garbage_detection_system/Garbage_Final/data.yaml",
    epochs=60,
    imgsz=640,
    batch=16,
    device='cpu'
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4547/3314743489.py in <cell line: 0>()
# ----> 1 results = model.train(
#       2     data="/content/drive/MyDrive/Colab Notebooks/Garbage_detection_system/Garbage_Final/data.yaml",
#       3     epochs=60,
#       4     imgsz=640,
#       5     batch=16,
#
# NameError: name 'model' is not defined

# %%
# !cp /content/runs/detect/train/weights/best.pt \
"/content/drive/MyDrive/Colab Notebooks/Garbage_detection_system/best.pt"
# Out:
# cp: cannot stat '/content/runs/detect/train/weights/best.pt': No such file or directory
